# %%
import numpy as np
import matplotlib.pylab as plt
import skimage
cafe = skimage.data.coffee()
# Out:
# /home/mauricio/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
plt.imshow(cafe)

# %% [markdown]
# #### Ejercicio1:
# Concatena la imagen del café consigo misma según los dos ejes.

# %%
plt.imshow(np.vstack((cafe, cafe)))

# %%
plt.imshow(np.hstack((cafe, cafe)))

# %% [markdown]
# #### Ejercicio 2:
# Usa transpose para obtener las imágenes de las ambas concatenaciones vistas en vertical.

# %%
vertical_T = np.vstack((cafe, cafe)).transpose((1,0,2))

# %%
plt.imshow(vertical_T)

# %%
vertical_H = np.hstack((cafe, cafe)).transpose((1,0,2))

# %%
plt.imshow(vertical_H)

# %% [markdown]
# #### Ejercicio 3:
# Usa split para trocear la imagen en cuatro partes. Concatena los trozos en el orden que te apetezca y visualiza la imagen.

# %%
cafe_split = np.split(cafe, 4)
plt.imshow(np.hstack((cafe_split[0], cafe_split[1],cafe_split[2], cafe_split[3])))

# %% [markdown]
# #### Ejercicio 4:
# Crear array con distribución normal de media 𝜇=0 y deviaciónn 𝜎=0.2. Su configuración debe responder a la tupla(20,100).
# Concatena esa matriz con otra de 20 filas llena de unos (compatible para concatenar por filas) y muestra la imagen.

# %%
mu, sigma, quantity = 0, 0.2, 2000
arr = np.random.normal(mu, sigma, quantity).reshape(20,100)
arr2 = np.ones((20,arr.shape[1]))
arr.shape
# Out:
# (20, 100)

# %%
arr_concat = np.concatenate((arr, arr2), axis=0)
arr_concat.shape
plt.imshow(arr_concat)

# %% [markdown]
# #### Ejercicio 5:
# Crea una función como la de la y's del Ej2 de la sesión anterior con shape(100,).
# Usa la matriz normal del EJ4. Puedes pensar que cada fila de la normal es un ruido aplicable a la de las y's.
# Calcula la matriz de todas las modificaciones por ruido.
# Muestra la matriz normal y la de las modificaciones por ruido.

# %% [markdown]
# $8Sen(x)*e^{-0.2x}$

# %%
xarray = np.linspace(0,4,100)
yarray = 8*np.sin(xarray)*np.exp(-0.2*xarray)
yarray.shape
# Out:
# (100,)

# %%
funcion_per = yarray + arr

# %%
funcion_per
# Out:
# array([[-0.02601857,  0.36613248,  0.6959208 , ..., -2.64177931,
#         -3.03402201, -2.4900261 ],
#        [-0.1803322 ,  0.24575035,  0.50692228, ..., -2.38803291,
#         -2.46962869, -2.73532177],
#        [ 0.01508043,  0.38821356,  0.37695921, ..., -2.354544  ,
#         -2.38785651, -2.61902629],
#        ...,
#        [-0.29537251,  0.26098456,  0.75899854, ..., -2.61991268,
#         -2.79870234, -2.83030142],
#        [-0.25303021, -0.09178558,  1.15785135, ..., -2.50094231,
#         -2.49656459, -2.95772664],
#        [-0.04210168,  0.21184083,  0.5705833 , ..., -2.69091153,
#         -2.40871953, -2.52291069]])

# %%
plt.plot(xarray, (funcion_per)[1])

# %% [markdown]
# #### Ejercicio 6:
# Parte de la matriz de la imagen del café. Hazle pequeñas modificaciones aplicando pesos a los canales y observa los resultados.
# Prueba a tratar cada color de forma independiente y luego usa stack para reconstruir.
#
# Usa split y aplica pesos diferentes en cada trozo.

# %%
cafe*[1,0,0]
plt.imshow(cafe*[1,0,0])

# %%
cafe_canal1 = cafe[:,:,0]*0.5
cafe_canal2 = cafe[:,:,1]*0.5
cafe_canal3 = cafe[:,:,2]*0.5

# %%
plt.imshow(cafe_canal1)

# %%
plt.imshow(cafe_canal2)

# %%
plt.imshow(cafe_canal3)

# %%
cafe_reconstruction = np.stack((cafe_canal1, cafe_canal2, cafe_canal3),axis=2)
plt.imshow(cafe_reconstruction)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
